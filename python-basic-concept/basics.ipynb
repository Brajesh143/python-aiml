# %%
a = 10;
a
# Out:
# 10

# %%
id(a)
# Out:
# 135463701578256

# %%
a=20
id(a)
# Out:
# 135463701578576

# %%
_
# Out:
# 135463701578576

# %%
b = 100
_
# Out:
# 135463701578576

# %%
a = 1000
a
# Out:
# 1000

# %%
a = 20000

# %%
a
# Out:
# 20000

# %%
a = 2000

# %%
x = 100
x
id(x)
# Out:
# 135463701581136

# %%
x = 200

# %%
id(x)
# Out:
# 135463701584336

# %%
_
# Out:
# 135463701584336

# %%
y = 300

# %%
_
# Out:
# 135463701584336

# %%
y = 400

# %%
y
# Out:
# 400

# %%
_
# Out:
# 400

# %%
a = 100
b = 200
c = a | b
c
# Out:
# 236

# %%
c = a/b

# %%
c
# Out:
# 0.5

# %%
c = a // b
c
# Out:
# 0

# %%
a = 10
b = 5
c = a//b
c
# Out:
# 2

# %%
a = 50
c = a // b
c
# Out:
# 10

# %%
b = 50
c = a//b
c
# Out:
# 1

# %%
a = 10
b = 20
c = a / b
c
d = a // b
d
# Out:
# 0

# %%
a = 10
b = 20
c = a % b
c
# Out:
# 10

# %%
a = 50
c = a % b
c
# Out:
# 10

# %%
a = 40
c = a % b
c
# Out:
# 0

# %%
a = 5
id(a)
# Out:
# 135463701578096

# %%
b= 5
id(b)
# Out:
# 135463701578096

# %%
b = 20
id(b)
# Out:
# 135463701578576
